# %%
import pandas as pd
import os

import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = '{}/nem-data/nemde_clean/df_DUID_CO2_mean.pkl'.format(os.environ['HOME'])
df_mean = pd.read_pickle(file_path)
df_mean.head()
# Out:
#                         Price  CO2E_EMISSIONS_FACTOR
# 2019-08-01 03:55:00  79.52391               0.380340
# 2019-08-01 03:50:00  79.17710               0.456409
# 2019-08-01 03:45:00  85.14416               0.573436
# 2019-08-01 03:40:00  84.78689               0.573436
# 2019-08-01 03:35:00  84.78346               0.573436

# %%
fig = sns.scatterplot(df_mean.CO2E_EMISSIONS_FACTOR, df_mean.Price)
fig.set_yscale("log")
fig.set_ylim(0,14000)
plt.figure();
# Out:
# /home/bastian/Environment/DSR_portfolio/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
group_year = df_mean.groupby(df_mean.index.year).mean()
group_quarter = df_mean.groupby(df_mean.index.quarter).mean()
group_month = df_mean.groupby(df_mean.index.month).mean()
group_week = df_mean.groupby(df_mean.index.week).mean()
group_day = df_mean.groupby(df_mean.index.day).mean()
group_hour = df_mean.groupby(df_mean.index.hour).mean()
group_minute = df_mean.groupby(df_mean.index.minute).mean()

#quarter: Quarter of the date: Jan-Mar = 1, Apr-Jun = 2, etc.

# %%
time_periods = {"year":group_year,"quarter":group_quarter, "month":group_month, "week":group_week,\
                "day":group_day, "hour":group_hour, "minute":group_minute}

# %%
for i in time_periods:
    fig = sns.scatterplot(time_periods[i].index, time_periods[i].CO2E_EMISSIONS_FACTOR)
    fig.set(xlabel = i, ylabel = "CO2")
    plt.figure()

# %%
group_year_month = df_mean.groupby([df_mean.index.year, df_mean.index.month]).mean()
group_year_month
# Out:
#               Price  CO2E_EMISSIONS_FACTOR
# 2009 7    27.446231               0.712181
#      8    22.771027               0.746957
#      9    27.074297               0.714911
#      10   27.976296               0.643430
#      11  197.206615               0.638268
# ...             ...                    ...
# 2019 4    93.843876               0.542918
#      5    84.855051               0.510462
#      6    95.702142               0.501340
#      7    73.927118               0.554505
#      8    89.618058               0.535162
#
# [122 rows x 2 columns]

# %%
df_unstacked = group_year_month.unstack(level=0).CO2E_EMISSIONS_FACTOR

fig, axes = plt.subplots(nrows=2, ncols=6, figsize=(15,7))
plt.tight_layout()

count_k = 0
for i in range(axes.shape[0]):
    for j in axes[i]:
        j.set_xlim(1,12)
        j.set_ylim(0.45,0.95)
        j.set_xticks(list(range(2,13,2)))
        j.set_title(df_unstacked.columns[count_k])
        j.plot(df_unstacked.index, df_unstacked.iloc[:, count_k])
        count_k += 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-b31edc5a055d> in <module>
#      10         j.set_ylim(0.45,0.95)
#      11         j.set_xticks(list(range(2,13,2)))
# ---> 12         j.set_title(df_unstacked.columns[count_k])
#      13         j.plot(df_unstacked.index, df_unstacked.iloc[:, count_k])
#      14         count_k += 1
#
# ~/Environment/DSR_portfolio/lib/python3.6/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4278         if is_scalar(key):
#    4279             key = com.cast_scalar_indexer(key)
# -> 4280             return getitem(key)
#    4281
#    4282         if isinstance(key, slice):
#
# IndexError: index 11 is out of bounds for axis 0 with size 11

# %%
df_unstacked = group_year_month.unstack(level=0).CO2E_EMISSIONS_FACTOR

# %%
df_unstacked
# Out:
# PeriodID      2009      2010      2011      2012      2013      2014  \
# PeriodID
# 1              NaN  0.699457  0.655480  0.783358  0.762508  0.874584
# 2              NaN  0.625458  0.610721  0.776635  0.687033  0.808551
# 3              NaN  0.645102  0.616553  0.756958  0.717267  0.852429
# 4              NaN  0.668365  0.647906  0.662153  0.713688  0.799783
# 5              NaN  0.583924  0.604423  0.715107  0.676363  0.723618
# 6              NaN  0.550888  0.674476  0.575157  0.638230  0.693586
# 7         0.712181  0.640871  0.668183  0.692139  0.727168  0.684359
# 8         0.746957  0.615287  0.661123  0.738354  0.717231  0.610381
# 9         0.714859  0.623407  0.704685  0.710217  0.665992  0.592049
# 10        0.643430  0.633180  0.745119  0.671723  0.738580  0.807138
# 11        0.638252  0.635919  0.679952  0.617426  0.771785  0.776471
# 12        0.709864  0.725071  0.785263  0.829746  0.764892  0.789945
#
# PeriodID      2015      2016      2017      2018
# PeriodID
# 1         0.807080  0.779090  0.724257  0.596632
# 2         0.727536  0.741494  0.641374  0.597925
# 3         0.748992  0.729118  0.701825  0.642916
# 4         0.706933  0.779545  0.632058  0.608576
# 5         0.688686  0.709998  0.562308  0.549339
# 6         0.645222  0.637817  0.533984  0.767256
# 7         0.733954  0.722642  0.511428  0.597887
# 8         0.705031  0.703295  0.571258       NaN
# 9         0.671736  0.729655  0.674198       NaN
# 10        0.741610  0.591991  0.607297       NaN
# 11        0.804304  0.718727  0.611513       NaN
# 12        0.793317  0.821532  0.630126       NaN

# %%
df_unstacked.columns
# Out:
# Int64Index([2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], dtype='int64', name='PeriodID')

# %%
fig = sns.lineplot(df_unstacked.index, df_unstacked[2010])

# %%
df_resample = df_mean.resample("M").mean()
df_resample.head()
# Out:
#                  Price  CO2E_EMISSIONS_FACTOR
# 2009-07-31   27.446231               0.712181
# 2009-08-31   22.771027               0.746957
# 2009-09-30   27.074297               0.714911
# 2009-10-31   27.976296               0.643430
# 2009-11-30  197.206615               0.638268

# %%
df_resample.index
# Out:
# DatetimeIndex(['2009-07-31', '2009-08-31', '2009-09-30', '2009-10-31',
#                '2009-11-30', '2009-12-31', '2010-01-31', '2010-02-28',
#                '2010-03-31', '2010-04-30',
#                ...
#                '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28',
#                '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30',
#                '2019-07-31', '2019-08-31'],
#               dtype='datetime64[ns]', length=122, freq='M')

# %%
plt.figure(figsize=(12,6))
sns.lineplot(df_resample.index, df_resample.CO2E_EMISSIONS_FACTOR)
# Out:
# /home/bastian/Environment/DSR_portfolio/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(df_resample.CO2E_EMISSIONS_FACTOR, model='additive')
result.plot();

# %%
result = seasonal_decompose(df_resample.CO2E_EMISSIONS_FACTOR, model='multiplicative')
result.plot();
